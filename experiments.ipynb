# %% [markdown]
# Imports

# %%
import numpy as np

# %% [markdown]
# Data

# %%
# Example with 3 samples and 3 classes

sample_1 = [2.0, 1.0, 0.1]
sample_2 = [-1.2, 3.5, -0.5]
sample_3 = [1.8, 1.5, -2.0]

logits = np.array([sample_1, sample_2, sample_3])
logits, logits.shape
# Out:
# (array([[ 2. ,  1. ,  0.1],
#         [-1.2,  3.5, -0.5],
#         [ 1.8,  1.5, -2. ]]),
#  (3, 3))

# %%
# labels
labels_sparse = np.array([0, 1, 2])

labels_one_hot = np.array([
    [1, 0, 0],  # True class is index 0
    [0, 1, 0],  # True class is index 1
    [0, 0, 1]   # True class is index 2
])

labels_sparse.shape, labels_one_hot.shape
# Out:
# ((3,), (3, 3))

# %% [markdown]
# Softmax

# %%
from src.modules.activations import softmax

# %%
probabilities = softmax(logits)
# Out:
# calculating the numerator = e^x for each value of x in the input tensor of scores
# the numerator is [[1.0, 0.36787944117144233, 0.14956861922263506], [0.009095277101695816, 1.0, 0.01831563888873418], [1.0, 0.7408182206817179, 0.0223707718561656]]
# calculating the denominator = summing across the last dimension of the numerator (vocab_size)
# the denominator is [[1.5174480603940774], [1.02741091599043], [1.7631889925378834]]
# calculating the probabilities by dividing the numerator by the denominator
# the final probabilities are [[0.6590011388859679, 0.24243297070471392, 0.09856589040931818], [0.00885261871383556, 0.9733203963829742, 0.017826984903190166], [0.5671541758893519, 0.42015814743455576, 0.01268767667609231]]
# the shape of the probabilities is (3, 3)

# %% [markdown]
# Cross-Entropy Loss

# %%
from src.utils.optimisation import cross_entropy_loss_one_hot, cross_entropy_loss_sparse

# %%
loss_one_hot = cross_entropy_loss_one_hot(probabilities, labels_one_hot)
loss_one_hot
# Out:
# 1.6037320257364263

# %%
loss_sparse = cross_entropy_loss_sparse(probabilities, labels_sparse)
loss_sparse
# Out:
# 1.6037320257364263
